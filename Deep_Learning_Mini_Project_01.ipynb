# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os


from google.colab import drive
drive.mount('/content/drive')


os.chdir("/content/drive/My Drive/PS_2019_054/")
os.getcwd()


img = image.load_img("Training/B/Ba.1.jpg")


plt.imshow(img)


cv2.imread("Training/B/Ba.1.jpg").shape


train = ImageDataGenerator(rescale = 1/255)


validation = ImageDataGenerator(rescale = 1/255)


train_dataset = train.flow_from_directory('Training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')


validation_dataset = validation.flow_from_directory('Validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')


train_dataset.class_indices


train_dataset.classes


model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])


model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])






model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)




validation_dataset.class_indices


dir_path = 'Testing/'


for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()


  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'Ba' in Sinhala")
  else:
    print("This is Letter 'Ga' in Sinhala")
# Out:
# Mounted at /content/drive
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 96s 23s/step - loss: 13.9546 - accuracy: 0.5385 - val_loss: 1.1255 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 9s 2s/step - loss: 0.9878 - accuracy: 0.3333 - val_loss: 0.7693 - val_accuracy: 0.5000
# Epoch 3/30
# 5/5 [==============================] - 10s 2s/step - loss: 0.6945 - accuracy: 0.5333 - val_loss: 0.7161 - val_accuracy: 0.5000
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.7198 - accuracy: 0.5333 - val_loss: 0.6858 - val_accuracy: 0.5000
# Epoch 5/30
# 5/5 [==============================] - 9s 2s/step - loss: 1.0283 - accuracy: 0.6000 - val_loss: 0.6982 - val_accuracy: 0.5000
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.7330 - accuracy: 0.6154 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 7/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6609 - accuracy: 0.6000 - val_loss: 0.6893 - val_accuracy: 0.6700
# Epoch 8/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6874 - accuracy: 0.5333 - val_loss: 0.7321 - val_accuracy: 0.5000
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7278 - accuracy: 0.4667 - val_loss: 0.6876 - val_accuracy: 0.7800
# Epoch 10/30
# 5/5 [==============================] - 9s 2s/step - loss: 0.6657 - accuracy: 0.6667 - val_loss: 0.6692 - val_accuracy: 0.6600
# Epoch 11/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.7649 - accuracy: 0.4000 - val_loss: 0.6636 - val_accuracy: 0.6900
# Epoch 12/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7813 - accuracy: 0.4667 - val_loss: 0.6493 - val_accuracy: 0.7600
# Epoch 13/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.7690 - accuracy: 0.6667 - val_loss: 0.6204 - val_accuracy: 0.6900
# Epoch 14/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6733 - accuracy: 0.4667 - val_loss: 0.6334 - val_accuracy: 0.8200
# Epoch 15/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6237 - accuracy: 0.6667 - val_loss: 0.6101 - val_accuracy: 0.6200
# Epoch 16/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6786 - accuracy: 0.5333 - val_loss: 0.6334 - val_accuracy: 0.6100
# Epoch 17/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6292 - accuracy: 0.6923 - val_loss: 0.5055 - val_accuracy: 0.7900
# Epoch 18/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.7461 - accuracy: 0.6000 - val_loss: 0.5518 - val_accuracy: 0.7700
# Epoch 19/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6952 - accuracy: 0.7333 - val_loss: 0.4898 - val_accuracy: 0.8000
# Epoch 20/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.6096 - accuracy: 0.6000 - val_loss: 0.4636 - val_accuracy: 0.8100
# Epoch 21/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3908 - accuracy: 0.8667 - val_loss: 0.3314 - val_accuracy: 0.8900
# Epoch 22/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6727 - accuracy: 0.8000 - val_loss: 0.3499 - val_accuracy: 0.8900
# Epoch 23/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.6918 - accuracy: 0.6667 - val_loss: 0.4364 - val_accuracy: 0.7800
# Epoch 24/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.4244 - accuracy: 0.8000 - val_loss: 0.3063 - val_accuracy: 0.8800
# Epoch 25/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.4400 - accuracy: 0.8667 - val_loss: 0.3905 - val_accuracy: 0.8200
# Epoch 26/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3627 - accuracy: 0.7333 - val_loss: 0.2585 - val_accuracy: 0.9100
# Epoch 27/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3251 - accuracy: 0.8000 - val_loss: 0.2280 - val_accuracy: 0.9400
# Epoch 28/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2002 - accuracy: 0.9333 - val_loss: 0.2384 - val_accuracy: 0.9100
# Epoch 29/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2573 - accuracy: 0.8667 - val_loss: 0.2616 - val_accuracy: 0.8600
# Epoch 30/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.2486 - accuracy: 0.8667 - val_loss: 0.2782 - val_accuracy: 0.9000
# 1/1 [==============================] - 0s 127ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 52ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 55ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 49ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 43ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 61ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 54ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 52ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ba' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 40ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 45ms/step
# This is Letter 'Ga' in Sinhala
